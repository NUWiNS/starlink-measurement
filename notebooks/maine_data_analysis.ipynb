# %%
print("Parse all nuttcp tcp_downlink files in the directory structure and save the extracted data to a CSV file")

import pytz
from datetime import datetime

import os
import re 

def find_files(base_dir, prefix, suffix):
    target_files = []

    # Walk through the directory structure
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.startswith(prefix) and file.endswith(suffix):
                target_files.append(os.path.join(root, file))
    return target_files

def format_datetime_as_iso_8601(dt: datetime):
    """
    Format the time in the EDT timezone
    :param dt: 
    :return: 
    """
    return dt.isoformat()

def append_timezone(dt: datetime, timezone_str: str, is_dst: bool = True):
    timezone = pytz.timezone(timezone_str)
    dt_aware = timezone.localize(dt, is_dst=is_dst)  # is_dst=True for daylight saving time
    return dt_aware

def append_edt_timezone(dt: datetime, is_dst: bool = True):
    return append_timezone(dt, "US/Eastern", is_dst)

def parse_nuttcp_timestamp(timestamp):
    # Parse the timestamp in the format of "2024-05-27 15:00:00.000000"
    return datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S.%f")

def format_nuttcp_timestamp(dt_str: str):
    dt = parse_nuttcp_timestamp(dt_str)
    dt_edt = append_edt_timezone(dt)
    return format_datetime_as_iso_8601(dt_edt)


def parse_nuttcp_tcp_result(content):
    # Regular expression to match the target line
    pattern = re.compile(
        r"\[(.*?)\]\s+.*?=\s+([\d.]+)\s+Mbps\s+(\d+)\s+retrans\s+(\d+)\s+KB-cwnd"
    )
    
    extracted_data = []
    
    for line in content.splitlines():
        match = pattern.search(line)
        if match:
            dt, throughput, retrans, cwnd = match.groups()
            dt_isoformat = format_nuttcp_timestamp(dt)
            row = [dt_isoformat, throughput, retrans, cwnd]
            extracted_data.append(','.join(row))
    return extracted_data

def save_to_csv(data, output_file):
    header = ['time', 'throughput_mbps', 'retrans', 'cwnd_kb']
    with open(output_file, 'w') as f:
        f.write(','.join(header) + '\n')
        for line in data:
            f.write(line + '\n')


# Specify the base directory (update this path as per your directory structure)
base_directory = "../outputs/maine_starlink_trip/"
# Out:
# Parse all nuttcp tcp_downlink files in the directory structure and save the extracted data to a CSV file

# %%
def find_tcp_downlink_file(base_dir):
    return find_files(base_dir, prefix="tcp_downlink", suffix=".out")

# Find the target files
tcp_downlink_files = find_tcp_downlink_file(base_directory)

# Display the found files
if tcp_downlink_files:
    print("Found tcp_downlink files")
else:
    print("No tcp_downlink files found.")

# Example to read and print the content of the found files
for file in tcp_downlink_files:
    try:
        with open(file, 'r') as f:
            content = f.read()
            extracted_data = parse_nuttcp_tcp_result(content)
            csv_file_path = file.replace('.out', '.csv')
            save_to_csv(extracted_data, csv_file_path)
            print(f"Extracted data is saved to {csv_file_path}")
    except Exception as e:
        print(f"Error reading {file}: {e}")

# %%
def find_tcp_uplink_file(base_dir):
    return find_files(base_dir, prefix="tcp_uplink", suffix=".out")
tcp_uplink_files = find_tcp_uplink_file(base_directory)

# Example to read and print the content of the found files
for file in tcp_uplink_files:
    try:
        with open(file, 'r') as f:
            content = f.read()
            extracted_data = parse_nuttcp_tcp_result(content)
            csv_file_path = file.replace('.out', '.csv')
            save_to_csv(extracted_data, csv_file_path)
            print(f"Extracted data is saved to {csv_file_path}")
    except Exception as e:
        print(f"Error reading {file}: {e}")
# Out:
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/115627940/tcp_uplink_115856082.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/163732935/tcp_uplink_163956659.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/114332240/tcp_uplink_114557054.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/124017808/tcp_uplink_124237814.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/113156102/tcp_uplink_113424280.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/160604145/tcp_uplink_160832339.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/162104355/tcp_uplink_162327018.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/125701833/tcp_uplink_125930037.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/111644991/tcp_uplink_111905793.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/122412357/tcp_uplink_122635051.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/120928721/tcp_uplink_121153567.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/154051628/tcp_uplink_154117518.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/155304814/tcp_uplink_155521909.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/151224454/tcp_uplink_151452578.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/180302985/tcp_uplink_180531131.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/114618857/tcp_uplink_114847004.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/143131151/tcp_uplink_143359332.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/121342008/tcp_uplink_121610144.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/122730031/tcp_uplink_122958158.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/150003953/tcp_uplink_150232129.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/173316010/tcp_uplink_173536143.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/110431666/tcp_uplink_110657181.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/120007017/tcp_uplink_120235156.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/183512082/tcp_uplink_183740224.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/152531477/tcp_uplink_152759648.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/174842024/tcp_uplink_175059818.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/105448125/tcp_uplink_105456303.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/154101588/tcp_uplink_154329741.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/155438485/tcp_uplink_155706637.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/135307370/tcp_uplink_135535583.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/171855350/tcp_uplink_172123532.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/160850129/tcp_uplink_161118266.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/142425887/tcp_uplink_142654039.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/111843111/tcp_uplink_112111284.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/182058012/tcp_uplink_182325947.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/110122357/tcp_uplink_110133569.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/170550086/tcp_uplink_170816042.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/113305230/tcp_uplink_113533381.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/163554293/tcp_uplink_163818562.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/162205315/tcp_uplink_162433427.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/140803035/tcp_uplink_141031189.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/200312053/tcp_uplink_200540186.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/182827889/tcp_uplink_183056043.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/204406502/tcp_uplink_204628679.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/135951496/tcp_uplink_140216622.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/205543581/tcp_uplink_205811732.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/183922295/tcp_uplink_184150463.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/143732577/tcp_uplink_144000726.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/180354032/tcp_uplink_180622188.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/193234336/tcp_uplink_193502475.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/114055495/tcp_uplink_114313752.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/173857163/tcp_uplink_174124893.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/112846612/tcp_uplink_113112994.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/203208729/tcp_uplink_203436879.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/151739387/tcp_uplink_152001343.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/181541964/tcp_uplink_181810103.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/175241501/tcp_uplink_175509653.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/142428304/tcp_uplink_142656439.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/145108430/tcp_uplink_145336586.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/185055787/tcp_uplink_185319488.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/194710715/tcp_uplink_194938866.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/172730914/tcp_uplink_172958211.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/150316937/tcp_uplink_150539827.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/201656940/tcp_uplink_201925067.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/141141299/tcp_uplink_141409444.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/190241372/tcp_uplink_190509546.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/111436693/tcp_uplink_111704858.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/124016789/tcp_uplink_124244970.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/125701880/tcp_uplink_125930078.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/122412520/tcp_uplink_122640811.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/114332366/tcp_uplink_114600559.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/115627091/tcp_uplink_115855255.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/120929014/tcp_uplink_121157191.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/113153867/tcp_uplink_113411838.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/155303806/tcp_uplink_155531945.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/163731738/tcp_uplink_163959919.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/160601779/tcp_uplink_160829936.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/111644330/tcp_uplink_111912535.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/162104332/tcp_uplink_162332504.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/154050643/tcp_uplink_154318844.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/142424051/tcp_uplink_142652237.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/110429136/tcp_uplink_110646813.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/122726885/tcp_uplink_122955039.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/183511163/tcp_uplink_183739343.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/180256949/tcp_uplink_180519961.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/105450405/tcp_uplink_105707233.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/152535594/tcp_uplink_152755948.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/170549903/tcp_uplink_170818057.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/113300251/tcp_uplink_113528438.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/150009226/tcp_uplink_150237377.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/154044418/tcp_uplink_154312583.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/151224628/tcp_uplink_151452789.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/143106371/tcp_uplink_143334553.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/111842936/tcp_uplink_112111115.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/163554275/tcp_uplink_163822426.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/114619458/tcp_uplink_114847631.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/155438558/tcp_uplink_155706720.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/135305155/tcp_uplink_135533352.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/173309012/tcp_uplink_173537187.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/182102977/tcp_uplink_182331180.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/140802606/tcp_uplink_141023562.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/162159169/tcp_uplink_162427312.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/121342335/tcp_uplink_121610510.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/174832187/tcp_uplink_175059901.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/120001854/tcp_uplink_120230000.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/171845809/tcp_uplink_172113960.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/160844627/tcp_uplink_161112785.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/190240845/tcp_uplink_190509031.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/204400316/tcp_uplink_204628506.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/203208065/tcp_uplink_203436236.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/175243458/tcp_uplink_175511671.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/173902759/tcp_uplink_173954111.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/205537592/tcp_uplink_205805743.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/183921942/tcp_uplink_184150101.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/135950908/tcp_uplink_140219124.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/201653253/tcp_uplink_201921470.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/194711058/tcp_uplink_194939216.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/172730772/tcp_uplink_172959012.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/150312984/tcp_uplink_150336801.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/151750658/tcp_uplink_152018831.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/111435209/tcp_uplink_111703421.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/145055420/tcp_uplink_145323585.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/181540627/tcp_uplink_181808816.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/114055889/tcp_uplink_114323108.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/141143054/tcp_uplink_141234497.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/193232220/tcp_uplink_193500396.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/185055165/tcp_uplink_185323331.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/180351116/tcp_uplink_180444785.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/142426435/tcp_uplink_142654631.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/182827093/tcp_uplink_183055280.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/143730951/tcp_uplink_143839972.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/200311438/tcp_uplink_200539640.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/112846014/tcp_uplink_113114202.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/155305385/tcp_uplink_155530056.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/111644607/tcp_uplink_111912791.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/125702552/tcp_uplink_125930782.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/163733373/tcp_uplink_164001544.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/122412886/tcp_uplink_122641140.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/120929421/tcp_uplink_121157595.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/114332708/tcp_uplink_114600881.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/124017121/tcp_uplink_124245319.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/154052223/tcp_uplink_154306876.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/115627411/tcp_uplink_115855591.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/162106142/tcp_uplink_162334290.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/160604865/tcp_uplink_160833020.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/113154194/tcp_uplink_113422403.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/121349644/tcp_uplink_121617776.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/174837282/tcp_uplink_175105441.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/180302008/tcp_uplink_180530183.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/142425432/tcp_uplink_142653620.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/155442744/tcp_uplink_155710907.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/152537622/tcp_uplink_152805826.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/110430503/tcp_uplink_110650046.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/173315063/tcp_uplink_173543214.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/154056047/tcp_uplink_154324198.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/113302130/tcp_uplink_113529159.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/170554559/tcp_uplink_170822741.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/111844288/tcp_uplink_112112441.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/105451878/tcp_uplink_105711129.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/163557697/tcp_uplink_163825139.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/162202780/tcp_uplink_162430931.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/151232763/tcp_uplink_151500938.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/150003474/tcp_uplink_150231691.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/183514567/tcp_uplink_183742736.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/143103915/tcp_uplink_143332115.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/182111112/tcp_uplink_182339249.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/140803552/tcp_uplink_141031755.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/122732314/tcp_uplink_122958726.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/135306964/tcp_uplink_135524461.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/160853918/tcp_uplink_161122069.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/114621502/tcp_uplink_114849670.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/171849203/tcp_uplink_172117352.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/120005237/tcp_uplink_120233359.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/173906836/tcp_uplink_174135073.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/114056693/tcp_uplink_114324866.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/181544481/tcp_uplink_181812640.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/142435059/tcp_uplink_142703262.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/190244593/tcp_uplink_190512772.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/135954030/tcp_uplink_140222234.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/185056564/tcp_uplink_185324729.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/193235082/tcp_uplink_193503248.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/141145588/tcp_uplink_141340785.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/151753605/tcp_uplink_152021606.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/143734533/tcp_uplink_143828113.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/150316794/tcp_uplink_150544980.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/175240997/tcp_uplink_175509195.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/145100357/tcp_uplink_145217905.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/112846835/tcp_uplink_113115006.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/200325447/tcp_uplink_200553625.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/194716638/tcp_uplink_194944807.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/201700299/tcp_uplink_201928551.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/205541763/tcp_uplink_205809942.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/180354875/tcp_uplink_180623045.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/183925400/tcp_uplink_184153559.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/172731782/tcp_uplink_173000003.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/203211534/tcp_uplink_203439762.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/111437116/tcp_uplink_111705340.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/182830616/tcp_uplink_183058777.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/204404414/tcp_uplink_204632611.csv
