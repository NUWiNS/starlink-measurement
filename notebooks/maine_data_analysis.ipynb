# %%
print("Parse all nuttcp tcp_downlink files in the directory structure and save the extracted data to a CSV file")

import pytz
from datetime import datetime
# Find downlink files in a directory structure

import os
import re 

def find_files(base_dir, prefix, suffix):
    target_files = []

    # Walk through the directory structure
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.startswith(prefix) and file.endswith(suffix):
                target_files.append(os.path.join(root, file))
    return target_files


def find_tcp_downlink_file(base_dir):
    return find_files(base_dir, prefix="tcp_downlink", suffix=".out")

def find_tcp_uplink_file(base_dir):
    return find_files(base_dir, prefix="tcp_uplink", suffix=".out")

def format_datetime_as_iso_8601(dt: datetime):
    """
    Format the time in the EDT timezone
    :param dt: 
    :return: 
    """
    return dt.isoformat()

def append_timezone(dt: datetime, timezone_str: str, is_dst: bool = True):
    timezone = pytz.timezone(timezone_str)
    dt_aware = timezone.localize(dt, is_dst=is_dst)  # is_dst=True for daylight saving time
    return dt_aware

def append_edt_timezone(dt: datetime, is_dst: bool = True):
    return append_timezone(dt, "US/Eastern", is_dst)

def parse_nuttcp_timestamp(timestamp):
    # Parse the timestamp in the format of "2024-05-27 15:00:00.000000"
    return datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S.%f")

def format_nuttcp_timestamp(dt_str: str):
    dt = parse_nuttcp_timestamp(dt_str)
    dt_edt = append_edt_timezone(dt)
    return format_datetime_as_iso_8601(dt_edt)


def parse_tcp_downlink_content(content):
    # Regular expression to match the target line
    pattern = re.compile(
        r"\[(.*?)\]\s+.*?=\s+([\d.]+)\s+Mbps\s+(\d+)\s+retrans\s+(\d+)\s+KB-cwnd"
    )
    
    extracted_data = []
    
    for line in content.splitlines():
        match = pattern.search(line)
        if match:
            dt, throughput, retrans, cwnd = match.groups()
            dt_isoformat = format_nuttcp_timestamp(dt)
            row = [dt_isoformat, throughput, retrans, cwnd]
            extracted_data.append(','.join(row))
    return extracted_data



def save_to_csv(data, output_file):
    header = ['time', 'throughput_mbps', 'retrans', 'cwnd_kb']
    with open(output_file, 'w') as f:
        f.write(','.join(header) + '\n')
        for line in data:
            f.write(line + '\n')


# Specify the base directory (update this path as per your directory structure)
base_directory = "../outputs/maine_starlink_trip/"

# Find the target files
tcp_downlink_files = find_tcp_downlink_file(base_directory)

# Display the found files
if tcp_downlink_files:
    print("Found tcp_downlink files")
else:
    print("No tcp_downlink files found.")

# Example to read and print the content of the found files
for file in tcp_downlink_files:
    try:
        with open(file, 'r') as f:
            content = f.read()
            extracted_data = parse_tcp_downlink_content(content)
            csv_file_path = file.replace('.out', '.csv')
            save_to_csv(extracted_data, csv_file_path)
            print(f"Extracted data is saved to {csv_file_path}")
    except Exception as e:
        print(f"Error reading {file}: {e}")
# Out:
# Found tcp_downlink files
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/115627940/tcp_downlink_115630977.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/163732935/tcp_downlink_163735969.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/114332240/tcp_downlink_114335268.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/124017808/tcp_downlink_124020848.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/113156102/tcp_downlink_113159143.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/160604145/tcp_downlink_160607172.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/162104355/tcp_downlink_162107388.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/125701833/tcp_downlink_125704870.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/111644991/tcp_downlink_111648027.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/122412357/tcp_downlink_122415394.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/120928721/tcp_downlink_120931766.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/154051628/tcp_downlink_154054663.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240529/155304814/tcp_downlink_155307849.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/151224454/tcp_downlink_151227484.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/180302985/tcp_downlink_180306021.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/114618857/tcp_downlink_114621885.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/143131151/tcp_downlink_143134189.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/121342008/tcp_downlink_121345035.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/122730031/tcp_downlink_122733063.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/150003953/tcp_downlink_150007013.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/173316010/tcp_downlink_173319048.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/110431666/tcp_downlink_110434704.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/120007017/tcp_downlink_120010052.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/183512082/tcp_downlink_183515114.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/152531477/tcp_downlink_152534513.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/174842024/tcp_downlink_174845062.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/105448125/tcp_downlink_105451163.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/154101588/tcp_downlink_154104618.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/155438485/tcp_downlink_155441523.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/135307370/tcp_downlink_135310417.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/171855350/tcp_downlink_171858397.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/160850129/tcp_downlink_160853159.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/142425887/tcp_downlink_142428919.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/111843111/tcp_downlink_111846150.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/182058012/tcp_downlink_182101046.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/110122357/tcp_downlink_110125395.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/170550086/tcp_downlink_170553118.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/113305230/tcp_downlink_113308263.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/163554293/tcp_downlink_163557331.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/162205315/tcp_downlink_162208344.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240527/140803035/tcp_downlink_140806061.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/200312053/tcp_downlink_200315083.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/182827889/tcp_downlink_182830918.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/204406502/tcp_downlink_204409541.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/135951496/tcp_downlink_135954530.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/205543581/tcp_downlink_205546619.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/183922295/tcp_downlink_183925333.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/143732577/tcp_downlink_143735615.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/180354032/tcp_downlink_180357057.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/193234336/tcp_downlink_193237373.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/114055495/tcp_downlink_114058528.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/173857163/tcp_downlink_173900219.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/112846612/tcp_downlink_112849659.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/203208729/tcp_downlink_203211763.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/151739387/tcp_downlink_151742413.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/181541964/tcp_downlink_181544994.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/175241501/tcp_downlink_175244535.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/142428304/tcp_downlink_142431340.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/145108430/tcp_downlink_145111461.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/185055787/tcp_downlink_185058829.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/194710715/tcp_downlink_194713753.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/172730914/tcp_downlink_172733946.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/150316937/tcp_downlink_150319974.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/201656940/tcp_downlink_201659975.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/141141299/tcp_downlink_141144336.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/190241372/tcp_downlink_190244426.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/starlink/20240528/111436693/tcp_downlink_111439722.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/124016789/tcp_downlink_124019830.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/125701880/tcp_downlink_125704924.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/122412520/tcp_downlink_122415567.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/114332366/tcp_downlink_114335405.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/115627091/tcp_downlink_115630125.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/120929014/tcp_downlink_120932053.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/113153867/tcp_downlink_113156901.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/155303806/tcp_downlink_155306847.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/163731738/tcp_downlink_163734776.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/160601779/tcp_downlink_160604823.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/111644330/tcp_downlink_111647379.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/162104332/tcp_downlink_162107362.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240529/154050643/tcp_downlink_154053686.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/142424051/tcp_downlink_142427104.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/110429136/tcp_downlink_110432184.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/122726885/tcp_downlink_122729929.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/183511163/tcp_downlink_183514197.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/180256949/tcp_downlink_180259984.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/105450405/tcp_downlink_105453440.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/152535594/tcp_downlink_152538639.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/170549903/tcp_downlink_170552937.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/113300251/tcp_downlink_113303289.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/150009226/tcp_downlink_150012253.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/154044418/tcp_downlink_154047463.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/151224628/tcp_downlink_151227664.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/143106371/tcp_downlink_143109416.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/110119073/tcp_downlink_110122108.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/111842936/tcp_downlink_111845962.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/163554275/tcp_downlink_163557319.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/114619458/tcp_downlink_114622495.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/155438558/tcp_downlink_155441601.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/135305155/tcp_downlink_135308204.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/173309012/tcp_downlink_173312050.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/182102977/tcp_downlink_182106016.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/140802606/tcp_downlink_140805656.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/162159169/tcp_downlink_162202209.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/121342335/tcp_downlink_121345377.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/174832187/tcp_downlink_174835231.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/120001854/tcp_downlink_120004895.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/171845809/tcp_downlink_171848846.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240527/160844627/tcp_downlink_160847667.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/190240845/tcp_downlink_190243886.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/204400316/tcp_downlink_204403358.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/203208065/tcp_downlink_203211102.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/175243458/tcp_downlink_175246507.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/173902759/tcp_downlink_173905801.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/205537592/tcp_downlink_205540629.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/183921942/tcp_downlink_183924975.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/135950908/tcp_downlink_135953963.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/201653253/tcp_downlink_201656296.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/194711058/tcp_downlink_194714092.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/172730772/tcp_downlink_172733824.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/150312984/tcp_downlink_150316016.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/151750658/tcp_downlink_151753697.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/111435209/tcp_downlink_111438247.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/145055420/tcp_downlink_145058459.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/181540627/tcp_downlink_181543670.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/114055889/tcp_downlink_114058929.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/141143054/tcp_downlink_141146097.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/193232220/tcp_downlink_193235266.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/185055165/tcp_downlink_185058203.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/180351116/tcp_downlink_180354159.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/142426435/tcp_downlink_142429475.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/182827093/tcp_downlink_182830135.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/143730951/tcp_downlink_143733993.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/200311438/tcp_downlink_200314481.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/verizon/20240528/112846014/tcp_downlink_112849047.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/155305385/tcp_downlink_155308429.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/111644607/tcp_downlink_111647649.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/125702552/tcp_downlink_125705598.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/163733373/tcp_downlink_163736399.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/122412886/tcp_downlink_122415951.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/120929421/tcp_downlink_120932457.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/114332708/tcp_downlink_114335746.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/124017121/tcp_downlink_124020163.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/154052223/tcp_downlink_154055262.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/115627411/tcp_downlink_115630449.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/162106142/tcp_downlink_162109175.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/160604865/tcp_downlink_160607903.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240529/113154194/tcp_downlink_113157234.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/110121019/tcp_downlink_110124054.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/121349644/tcp_downlink_121352681.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/174837282/tcp_downlink_174840320.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/180302008/tcp_downlink_180305050.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/142425432/tcp_downlink_142428477.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/155442744/tcp_downlink_155445777.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/152537622/tcp_downlink_152540680.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/110430503/tcp_downlink_110433554.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/173315063/tcp_downlink_173318090.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/154056047/tcp_downlink_154059087.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/113302130/tcp_downlink_113305170.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/170554559/tcp_downlink_170557601.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/111844288/tcp_downlink_111847325.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/105451878/tcp_downlink_105454920.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/163557697/tcp_downlink_163600726.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/162202780/tcp_downlink_162205807.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/151232763/tcp_downlink_151235800.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/150003474/tcp_downlink_150006512.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/183514567/tcp_downlink_183517608.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/143103915/tcp_downlink_143106964.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/182111112/tcp_downlink_182114146.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/140803552/tcp_downlink_140806597.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/122732314/tcp_downlink_122735346.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/135306964/tcp_downlink_135309996.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/160853918/tcp_downlink_160856947.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/114621502/tcp_downlink_114624546.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/171849203/tcp_downlink_171852241.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240527/120005237/tcp_downlink_120008273.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/173906836/tcp_downlink_173909885.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/114056693/tcp_downlink_114059736.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/181544481/tcp_downlink_181547508.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/142435059/tcp_downlink_142438099.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/190244593/tcp_downlink_190247626.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/135954030/tcp_downlink_135957074.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/185056564/tcp_downlink_185059595.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/193235082/tcp_downlink_193238110.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/141145588/tcp_downlink_141148634.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/151753605/tcp_downlink_151756646.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/143734533/tcp_downlink_143737560.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/150316794/tcp_downlink_150319835.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/175240997/tcp_downlink_175244031.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/145100357/tcp_downlink_145103399.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/112846835/tcp_downlink_112849875.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/200325447/tcp_downlink_200328496.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/194716638/tcp_downlink_194719679.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/201700299/tcp_downlink_201703355.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/205541763/tcp_downlink_205544802.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/180354875/tcp_downlink_180357920.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/183925400/tcp_downlink_183928430.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/172731782/tcp_downlink_172734838.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/203211534/tcp_downlink_203214576.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/111437116/tcp_downlink_111440159.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/182830616/tcp_downlink_182833655.csv
# Extracted data is saved to ../outputs/maine_starlink_trip/att/20240528/204404414/tcp_downlink_204407459.csv
