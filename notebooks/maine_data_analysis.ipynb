# %%
import pytz
from datetime import datetime

import os
import re


def find_files(base_dir, prefix, suffix):
    target_files = []

    # Walk through the directory structure
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.startswith(prefix) and file.endswith(suffix):
                target_files.append(os.path.join(root, file))
    return target_files


def format_datetime_as_iso_8601(dt: datetime):
    """
    Format the time in the EDT timezone
    :param dt: 
    :return: 
    """
    return dt.isoformat()


def append_timezone(dt: datetime, timezone_str: str, is_dst: bool = True):
    timezone = pytz.timezone(timezone_str)
    dt_aware = timezone.localize(dt, is_dst=is_dst)  # is_dst=True for daylight saving time
    return dt_aware


def append_edt_timezone(dt: datetime, is_dst: bool = True):
    return append_timezone(dt, "US/Eastern", is_dst)


def parse_nuttcp_timestamp(timestamp):
    # Parse the timestamp in the format of "2024-05-27 15:00:00.000000"
    return datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S.%f")


def format_nuttcp_timestamp(dt_str: str):
    dt = parse_nuttcp_timestamp(dt_str)
    dt_edt = append_edt_timezone(dt)
    return format_datetime_as_iso_8601(dt_edt)


def parse_nuttcp_tcp_result(content):
    # Regular expression to match the target line
    pattern = re.compile(
        r"\[(.*?)\]\s+.*?=\s+([\d.]+)\s+Mbps\s+(\d+)\s+retrans\s+(\d+)\s+KB-cwnd"
    )

    extracted_data = []

    for line in content.splitlines():
        match = pattern.search(line)
        if match:
            dt, throughput, retrans, cwnd = match.groups()
            dt_isoformat = format_nuttcp_timestamp(dt)
            row = [dt_isoformat, throughput, retrans, cwnd]
            extracted_data.append(','.join(row))
    return extracted_data

def parse_nuttcp_udp_result(content):
    pattern = re.compile(r'\[(.*?)\]\s+.*=\s+([\d.]+) Mbps\s+([-\d]+) /\s+(\d+) ~drop/pkt\s+([-\d.]+) ~%loss')

    extracted_data = []
    for line in content.splitlines():
        match = pattern.search(line)
        if match:
            dt, throughput, pkt_drop, pkt_total, loss = match.groups()
            dt_isoformat = format_nuttcp_timestamp(dt)
            row = [dt_isoformat, throughput, pkt_drop, pkt_total, loss]
            extracted_data.append(','.join(row))
    return extracted_data

def save_to_csv(data, output_file):
    header = ['time', 'throughput_mbps', 'retrans', 'cwnd_kb']
    with open(output_file, 'w') as f:
        f.write(','.join(header) + '\n')
        for line in data:
            f.write(line + '\n')
            
def save_udp_data_to_csv(data, output_file):
    header = ['time', 'throughput_mbps', 'pkt_drop', 'pkt_total', 'loss']
    with open(output_file, 'w') as f:
        f.write(','.join(header) + '\n')
        for line in data:
            f.write(line + '\n')
            
def find_tcp_downlink_file(base_dir):
    return find_files(base_dir, prefix="tcp_downlink", suffix=".out")

def find_tcp_uplink_file(base_dir):
    return find_files(base_dir, prefix="tcp_uplink", suffix=".out")

def find_udp_downlink_file(base_dir):
    return find_files(base_dir, prefix="udp_downlink", suffix=".out")

def find_udp_uplink_file(base_dir):
    return find_files(base_dir, prefix="udp_uplink", suffix=".out")

def find_ping_file(base_dir):
    return find_files(base_dir, prefix="ping", suffix=".out")

def find_traceroute_file(base_dir):
    return find_files(base_dir, prefix="traceroute", suffix=".out")

def find_nslookup_file(base_dir):
    return find_files(base_dir, prefix="nslookup", suffix=".out")

def count_subfolders(base_dir):
    return len(os.listdir(base_dir))

# Specify the base directory (update this path as per your directory structure)
base_directory = os.path.join(os.getcwd(), "../outputs/maine_starlink_trip/")

# %%
from typing import List, Dict
import pandas as pd


# Inspect datasets
# How many valid datasets are there?

def inspect_validity_of_files(file_path_list: List[str]):
    # Any file that has less than 4 lines is considered invalid
    valid_files = []
    invalid_files = []
    for file in file_path_list:
        line_count = 0
        with open(file, 'r') as f:
            # Read each line at a time to save memory
            for _ in f:
                line_count += 1
                if line_count >= 4:
                    break
        if line_count >= 4:
            valid_files.append(file)
        else:
            invalid_files.append(file)
    return {
        'total_count': len(file_path_list),
        'valid_count': len(valid_files),
        'invalid_count': len(invalid_files),
        'valid_files': valid_files,
        'invalid_files': invalid_files
    }
            


def inspect_datasets(base_dir, name):
    tcp_downlink_files = find_tcp_downlink_file(base_dir)
    tcp_uplink_files = find_tcp_uplink_file(base_dir)
    udp_downlink_files = find_udp_downlink_file(base_dir)
    udp_uplink_files = find_udp_uplink_file(base_dir)
    ping_files = find_ping_file(base_dir)
    traceroute_files = find_traceroute_file(base_dir)
    nslookup_files = find_nslookup_file(base_dir)
    
    return {
        'name': name,
        'base_dir': base_dir,
        'total_runs': count_subfolders(base_dir),
        'tcp_downlink_files': inspect_validity_of_files(tcp_downlink_files),
        'tcp_uplink_files': inspect_validity_of_files(tcp_uplink_files),
        'udp_downlink_files': inspect_validity_of_files(udp_downlink_files),
        'udp_uplink_files': inspect_validity_of_files(udp_uplink_files),
        'ping_files': inspect_validity_of_files(ping_files),
        'traceroute_files': inspect_validity_of_files(traceroute_files),
        'nslookup_files': inspect_validity_of_files(nslookup_files)
    }
    
def inspect_datasets_by_day():
    operators = ['att', 'verizon', 'starlink']
    
    def print_validity_summary(metric_name: str, validity_summary: Dict):
        total_len = validity_summary['total_count']
        valid_len = validity_summary['valid_count']
        invalid_len = validity_summary['invalid_count']
        print(f"-- {metric_name}:")
        print(f"---- total_files: {total_len}")
        print(f"---- valid_files: {valid_len}")
        print(f"---- invalid_files: {invalid_len}")
        
        
    def print_inspection(inspection: Dict):
        print('-----------------------------------')
        print(f"Inspection of datasets from {inspection['name']}")
        print('-- total_runs', inspection['total_runs'])
        print_validity_summary('tcp_downlink_files', inspection['tcp_downlink_files'])
        print_validity_summary('tcp_uplink_files', inspection['tcp_uplink_files'])
        print_validity_summary('udp_downlink_files', inspection['udp_downlink_files'])
        print_validity_summary('udp_uplink_files', inspection['udp_uplink_files'])
        print_validity_summary('ping_files', inspection['ping_files'])
        print_validity_summary('traceroute_files', inspection['traceroute_files'])
        print_validity_summary('nslookup_files', inspection['nslookup_files'])
        print('-----------------------------------')
     
    def print_runs_info(operator, day, runs):
        print(f"Operator: {operator}, Day: {day}, Runs: {runs}")


    data_list = []
    for operator in operators:
        operator_dir = os.path.join(base_directory, operator)
        for day in os.listdir(operator_dir):
            operator_day_dir = os.path.join(operator_dir, day)
            data_name = f"{operator}_{day}"
            inspection = inspect_datasets(operator_day_dir, data_name)
            # print_inspection(inspection)
            data_list.append({
                'operator': operator,
                'day': day,
                'runs': inspection['total_runs'],
                'tcp.dl.valid': inspection['tcp_downlink_files']['valid_count'],
                'tcp.ul.valid': inspection['tcp_uplink_files']['valid_count'],
                'udp.dl.valid': inspection['udp_downlink_files']['valid_count'],
                'udp.ul.valid': inspection['udp_uplink_files']['valid_count'],
                'ping.valid': inspection['ping_files']['valid_count'],
                'traceroute.valid': inspection['traceroute_files']['valid_count'],
                'nslookup.valid': inspection['nslookup_files']['valid_count']
            })
            
            # print_runs_info(operator, day, inspection['total_runs'])
    # sort the list by operator and day
    data_list = sorted(data_list, key=lambda x: (x['operator'], x['day']))
    df = pd.DataFrame(data_list)
    df.to_csv(os.path.join(base_directory, 'dataset_inspection_summary.csv'), index=False)
    print('Inspection summary is saved to dataset_inspection_summary.csv')
    
inspect_datasets_by_day()

# %%
# Save the extracted nuttcp data of TCP DL to csv files 

# Find the target files
tcp_downlink_files = find_tcp_downlink_file(base_directory)

# Display the found files
if tcp_downlink_files:
    print("Found tcp_downlink files")
else:
    print("No tcp_downlink files found.")

# Example to read and print the content of the found files
for file in tcp_downlink_files:
    try:
        with open(file, 'r') as f:
            content = f.read()
            extracted_data = parse_nuttcp_tcp_result(content)
            csv_file_path = file.replace('.out', '.csv')
            save_to_csv(extracted_data, csv_file_path)
            print(f"Extracted data is saved to {csv_file_path}")
    except Exception as e:
        print(f"Error reading {file}: {e}")

# %%
# Save the extracted nuttcp data of TCP UL to csv files

def find_tcp_uplink_file(base_dir):
    return find_files(base_dir, prefix="tcp_uplink", suffix=".out")


tcp_uplink_files = find_tcp_uplink_file(base_directory)

# Example to read and print the content of the found files
for file in tcp_uplink_files:
    try:
        with open(file, 'r') as f:
            content = f.read()
            extracted_data = parse_nuttcp_tcp_result(content)
            csv_file_path = file.replace('.out', '.csv')
            save_to_csv(extracted_data, csv_file_path)
            print(f"Extracted data is saved to {csv_file_path}")
    except Exception as e:
        print(f"Error reading {file}: {e}")

# %%
print("Save the extracted nuttcp data of UDP UL to csv files")

def find_udp_uplink_file(base_dir):
    return find_files(base_dir, prefix="udp_uplink", suffix=".out")

udp_uplink_files = find_udp_uplink_file(base_directory)
excluded_files = []

# Example to read and print the content of the found files
for file in udp_uplink_files:
    # exclude the data on 20240527 because of the uplink metrics are from the sender side instead of the receiver side
    if '20240527' in file:
        excluded_files.append(file)
        continue
    try:
        with open(file, 'r') as f:
            content = f.read()
            extracted_data = parse_nuttcp_udp_result(content)
            csv_file_path = file.replace('.out', '.csv')
            save_udp_data_to_csv(extracted_data, csv_file_path)
            print(f"Extracted data is saved to {csv_file_path}")
    except Exception as e:
        print(f"Error reading {file}: {e}")
        
print('Total files:', len(udp_uplink_files))
print('Excluded files:', len(excluded_files))
# Out:
# Save the extracted nuttcp data of UDP UL to csv files
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/162625440/udp_uplink_162834071.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/120154220/udp_uplink_120403096.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/112204079/udp_uplink_112412958.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/161130603/udp_uplink_161339478.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/121451555/udp_uplink_121700241.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/113722731/udp_uplink_113931996.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/122935986/udp_uplink_123145381.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/124538278/udp_uplink_124747023.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/130228180/udp_uplink_130437171.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/114855416/udp_uplink_115104079.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/154557400/udp_uplink_154615677.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/164255340/udp_uplink_164505442.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/113411313/udp_uplink_113620231.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/142955488/udp_uplink_143204887.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/203736608/udp_uplink_203946291.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/111833299/udp_uplink_112041883.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/202224468/udp_uplink_202433158.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/193802473/udp_uplink_194011402.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/195238106/udp_uplink_195447244.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/152303814/udp_uplink_152516844.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/140514969/udp_uplink_140727719.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/174423046/udp_uplink_174631742.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/190809371/udp_uplink_191018162.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/185618946/udp_uplink_185828713.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/204927647/udp_uplink_205136868.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/180922162/udp_uplink_181130877.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/175809947/udp_uplink_180018598.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/145636181/udp_uplink_145846888.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/173257979/udp_uplink_173507945.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/183355447/udp_uplink_183604432.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/210111425/udp_uplink_210321178.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/182226043/udp_uplink_182234243.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/114612944/udp_uplink_114821627.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/144259297/udp_uplink_144508052.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/141712006/udp_uplink_141920744.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/200839428/udp_uplink_201048389.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/150839391/udp_uplink_151048827.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/184449732/udp_uplink_184658652.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/112212640/udp_uplink_112440809.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/161132665/udp_uplink_161400840.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/130243087/udp_uplink_130511283.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/114902206/udp_uplink_115130377.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/155830105/udp_uplink_160058311.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/162631810/udp_uplink_162859990.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/120157020/udp_uplink_120425198.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/113710773/udp_uplink_113938959.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/124543974/udp_uplink_124812154.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/121457421/udp_uplink_121725613.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/122940470/udp_uplink_123208636.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/164300748/udp_uplink_164528925.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240529/154622705/udp_uplink_154850880.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/174327263/udp_uplink_174526577.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/113424924/udp_uplink_113635728.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/140532820/udp_uplink_140800969.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/144157357/udp_uplink_144425515.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/202221903/udp_uplink_202450088.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/210122964/udp_uplink_210351149.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/114625830/udp_uplink_114836934.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/173322615/udp_uplink_173550809.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/182110602/udp_uplink_182338806.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/200932227/udp_uplink_201145120.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/141641167/udp_uplink_141909289.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/184507521/udp_uplink_184735694.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/111902584/udp_uplink_112123493.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/175741956/udp_uplink_180010161.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/152339149/udp_uplink_152548718.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/145444720/udp_uplink_145557772.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/204926694/udp_uplink_205154900.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/193809070/udp_uplink_194037232.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/183309862/udp_uplink_183538037.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/180605474/udp_uplink_180833665.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/195237791/udp_uplink_195505973.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/185651468/udp_uplink_185919650.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/203747064/udp_uplink_204015264.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/190810761/udp_uplink_191038971.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/142953265/udp_uplink_143221447.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/150657222/udp_uplink_150925378.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/162640954/udp_uplink_162851206.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/130245511/udp_uplink_130455394.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/120218544/udp_uplink_120434093.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/123003598/udp_uplink_123213710.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/114907335/udp_uplink_115119563.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/112225227/udp_uplink_112435621.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/155834834/udp_uplink_160044475.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/164313466/udp_uplink_164525270.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/154612513/udp_uplink_154825578.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/113732375/udp_uplink_113942746.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/161153561/udp_uplink_161402833.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/121508222/udp_uplink_121718519.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240529/124535371/udp_uplink_124744748.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/182117304/udp_uplink_182345513.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/193816854/udp_uplink_194045060.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/200900691/udp_uplink_201111232.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/180936686/udp_uplink_181149310.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/112021995/udp_uplink_112232756.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/140529187/udp_uplink_140743180.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/203747027/udp_uplink_203956740.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/210122014/udp_uplink_210333965.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/184501807/udp_uplink_184713045.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/113423086/udp_uplink_113633550.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/143026153/udp_uplink_143242062.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/173305675/udp_uplink_173516175.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/143956363/udp_uplink_144224570.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/141648072/udp_uplink_141916295.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/202245896/udp_uplink_202458343.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/150849027/udp_uplink_151059066.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/183321072/udp_uplink_183549286.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/114631199/udp_uplink_114841659.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/152326454/udp_uplink_152536260.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/174458039/udp_uplink_174726221.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/204942011/udp_uplink_205156179.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/195250742/udp_uplink_195501807.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/185651277/udp_uplink_185901756.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/190827527/udp_uplink_191037835.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/145536815/udp_uplink_145748936.csv
# Extracted data is saved to /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/175537244/udp_uplink_175805434.csv
# Total files: 191
# Excluded files: 75

# %%
# Plot CDF of throughput

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd


def read_csv_files(file_pattern):
    files = glob.glob(file_pattern, recursive=True)
    data_frames = []

    empty_file_count = 0
    total_file_count = 0

    for file in files:
        total_file_count += 1
        operator = extract_operator_from_filename(file)
        df = pd.read_csv(file)
        if df.empty:
            empty_file_count += 1
            print("--- Empty file detected: ", file)
            continue

        df['operator'] = operator
        data_frames.append(df)

    print(f"Total files processed: {total_file_count}")
    print(f"Empty files detected and skipped: {empty_file_count}")
    return pd.concat(data_frames, ignore_index=True)


def extract_throughput_df(data_frame, operator=None):
    df = data_frame.copy()
    if operator:
        df = df[df['operator'] == operator]
    return df['throughput_mbps']


def extract_operator_from_filename(file_path):
    """
    :param file_path: assume the format like /path/to/starlink/20240529/115627940/tcp_downlink_115630977.csv 
    :return: the operator name, e.g. starlink
    """
    operator = file_path.split(os.sep)[-4]  # Adjust based on the exact structure of your file paths
    return operator

def get_data_frame_from_all_csv(protocol, direction):
    filename_pattern = os.path.join(base_directory, f'**/{protocol}_{direction}_*.csv')
    data_frame = read_csv_files(filename_pattern)
    return data_frame
    

def save_throughput_metric_to_csv(data_frame, protocol, direction, output_dir='.'):
    """
    :param data_frame:
    :param protocol: tcp | udp 
    :param direction:  uplink | downlink
    :param output_dir: 
    :return: 
    """
    prefix = f"{protocol}_{direction}"
    csv_filepath = os.path.join(output_dir, f'{prefix}_all.csv')
    data_frame.to_csv(csv_filepath, index=False)
    print(f'save all the {prefix} data to csv file: {csv_filepath}')

# %%
dataset_dir = os.path.join(base_directory, 'datasets')
if not os.path.exists(dataset_dir):
    os.makedirs(dataset_dir, exist_ok=True)

print('-----------------------------------')
all_tcp_downlink_df = get_data_frame_from_all_csv('tcp', 'downlink')
save_throughput_metric_to_csv(data_frame=all_tcp_downlink_df, protocol='tcp', direction='downlink', output_dir=dataset_dir)

print('-----------------------------------')

all_tcp_uplink_df = get_data_frame_from_all_csv('tcp', 'uplink')
save_throughput_metric_to_csv(data_frame=all_tcp_uplink_df, protocol='tcp', direction='uplink', output_dir=dataset_dir)

print('-----------------------------------')

all_udp_uplink_df = get_data_frame_from_all_csv('udp', 'uplink')
save_throughput_metric_to_csv(data_frame=all_udp_uplink_df, protocol='udp', direction='uplink', output_dir=dataset_dir)
# Out:
# -----------------------------------
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/154051628/tcp_downlink_154054663.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/155304814/tcp_downlink_155307849.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240527/105448125/tcp_downlink_105451163.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240527/110122357/tcp_downlink_110125395.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/145055420/tcp_downlink_145058459.csv
# Total files processed: 202
# Empty files detected and skipped: 5
# save all the tcp_downlink data to csv file: /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/datasets/tcp_downlink_all.csv
# -----------------------------------
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/155304814/tcp_uplink_155521909.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240527/105448125/tcp_uplink_105456303.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240527/110122357/tcp_uplink_110133569.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/145055420/tcp_uplink_145323585.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/180351116/tcp_uplink_180444785.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/143734533/tcp_uplink_143828113.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/175240997/tcp_uplink_175509195.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/att/20240528/145100357/tcp_uplink_145217905.csv
# Total files processed: 200
# Empty files detected and skipped: 8
# save all the tcp_uplink data to csv file: /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/datasets/tcp_uplink_all.csv
# -----------------------------------
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240529/154557400/udp_uplink_154615677.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/starlink/20240528/182226043/udp_uplink_182234243.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/173322615/udp_uplink_173550809.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/141641167/udp_uplink_141909289.csv
# --- Empty file detected:  /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/verizon/20240528/145444720/udp_uplink_145557772.csv
# Total files processed: 117
# Empty files detected and skipped: 5
# save all the udp_uplink data to csv file: /Users/bruski/workspace/projects/starlink/starlink-measurement/notebooks/../outputs/maine_starlink_trip/datasets/udp_uplink_all.csv

# %%
def plot_cdf_of_throughput(
        data_frame,
        xlabel='Throughput (Mbps)',
        ylabel='CDF',
        title='CDF of Throughput',
        output_file_path=None
):
    data_sorted = np.sort(data_frame)
    cdf = np.arange(1, len(data_sorted) + 1) / len(data_sorted)

    plt.figure(figsize=(10, 6))
    plt.plot(data_sorted, cdf, linestyle='-')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    if output_file_path:
        plt.savefig(output_file_path)
    plt.show()


def plot_cdf_of_throughput_with_all_operators(
        df,
        xlabel='Throughput (Mbps)',
        ylabel='CDF',
        title='CDF of Throughput with all Operators',
        output_file_path=None
):
    plt.figure(figsize=(10, 6))

    operators = ['starlink', 'att', 'verizon']
    colors = ['r', 'g', 'b']

    for index, operator in enumerate(operators):
        operator_data = extract_throughput_df(df, operator)
        data_sorted = np.sort(operator_data)
        color = colors[index]
        cdf = np.arange(1, len(data_sorted) + 1) / len(data_sorted)
        plt.plot(
            data_sorted,
            cdf,
            color=color,
            linestyle='-',
            label=f'{operator}'
        )

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.grid(True)
    if output_file_path:
        plt.savefig(output_file_path)
    plt.show()


def plot_tcp_downlink_data(df, output_dir='.'):
    operators = df['operator'].unique()

    # plot CDF of throughput for each operator
    for operator in operators:
        throughput_df = extract_throughput_df(df, operator)
        plot_cdf_of_throughput(
            throughput_df,
            title=f'CDF of TCP Downlink Throughput ({operator.capitalize()})',
            output_file_path=os.path.join(output_dir, f'cdf_tcp_downlink_{operator}.png')
        )

    # plot one CDF of throughput for all operators
    plot_cdf_of_throughput_with_all_operators(
        df,
        title='CDF of TCP Downlink Throughput (All Operators)',
        output_file_path=os.path.join(output_dir, f'cdf_tcp_downlink_all.png')
    )
    
def plot_tcp_uplink_data(df: pd.DataFrame, output_dir='.'):
    operators = df['operator'].unique()

    # plot CDF of throughput for each operator
    for operator in operators:
        throughput_df = extract_throughput_df(df, operator)
        plot_cdf_of_throughput(
            throughput_df,
            title=f'CDF of TCP Uplink Throughput ({operator.capitalize()})',
            output_file_path=os.path.join(output_dir, f'cdf_tcp_uplink_{operator}.png')
        )

    # plot one CDF of throughput for all operators
    plot_cdf_of_throughput_with_all_operators(
        df,
        title='CDF of TCP Uplink Throughput (All Operators)',
        output_file_path=os.path.join(output_dir, f'cdf_tcp_uplink_all.png')
    )
    
def plot_udp_uplink_data(df: pd.DataFrame, output_dir='.'):
    operators = df['operator'].unique()

    # plot CDF of throughput for each operator
    for operator in operators:
        throughput_df = extract_throughput_df(df, operator)
        plot_cdf_of_throughput(
            throughput_df,
            title=f'CDF of UDP Uplink Throughput ({operator.capitalize()})',
            output_file_path=os.path.join(output_dir, f'cdf_udp_uplink_{operator}.png')
        )

    # plot one CDF of throughput for all operators
    plot_cdf_of_throughput_with_all_operators(
        df,
        title='CDF of UDP Uplink Throughput (All Operators)',
        output_file_path=os.path.join(output_dir, f'cdf_udp_uplink_all.png')
    )

# %%
# Plot the CDF of throughput

output_plots_dir = os.path.join(base_directory, 'plots')
if not os.path.exists(output_plots_dir):
    os.makedirs(output_plots_dir, exist_ok=True)

# plot_tcp_downlink_data(all_tcp_downlink_df, output_dir=output_plots_dir)
# plot_tcp_uplink_data(all_tcp_uplink_df, output_dir=output_plots_dir)
plot_udp_uplink_data(df=all_udp_uplink_df, output_dir=output_plots_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 9
#       5     os.makedirs(output_plots_dir, exist_ok=True)
#       7 # plot_tcp_downlink_data(all_tcp_downlink_df, output_dir=output_plots_dir)
#       8 # plot_tcp_uplink_data(all_tcp_uplink_df, output_dir=output_plots_dir)
# ----> 9 plot_udp_uplink_data(df=all_udp_uplink_df, output_dir=output_plots_dir)
#
# Cell In[9], line 99, in plot_udp_uplink_data(df, output_dir)
#      96 operators = df['operator'].unique()
#      98 # plot CDF of throughput for each operator
# ---> 99 for operator in operators:
#     100     throughput_df = extract_throughput_df(df, operator)
#     101     plot_cdf_of_throughput(
#     102         throughput_df,
#     103         title=f'CDF of UDP Uplink Throughput ({operator.capitalize()})',
#     104         output_file_path=os.path.join(output_dir, f'cdf_udp_uplink_{operator}.png')
#     105     )
#
# Cell In[9], line 99, in plot_udp_uplink_data(df, output_dir)
#      96 operators = df['operator'].unique()
#      98 # plot CDF of throughput for each operator
# ---> 99 for operator in operators:
#     100     throughput_df = extract_throughput_df(df, operator)
#     101     plot_cdf_of_throughput(
#     102         throughput_df,
#     103         title=f'CDF of UDP Uplink Throughput ({operator.capitalize()})',
#     104         output_file_path=os.path.join(output_dir, f'cdf_udp_uplink_{operator}.png')
#     105     )
#
# File _pydevd_bundle/pydevd_cython_darwin_310_64.pyx:1187, in _pydevd_bundle.pydevd_cython_darwin_310_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_310_64.pyx:627, in _pydevd_bundle.pydevd_cython_darwin_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_310_64.pyx:937, in _pydevd_bundle.pydevd_cython_darwin_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_310_64.pyx:928, in _pydevd_bundle.pydevd_cython_darwin_310_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_310_64.pyx:585, in _pydevd_bundle.pydevd_cython_darwin_310_64.PyDBFrame.do_wait_suspend()
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1187, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1184         from_this_thread.append(frame_id)
#    1186 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1187     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1202, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1199             self._call_mpl_hook()
#    1201         self.process_internal_commands()
# -> 1202         time.sleep(0.01)
#    1204 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1206 # process any stepping instructions
#
# KeyboardInterrupt:
